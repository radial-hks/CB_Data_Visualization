# %%
'''
【课程5.3】  图表辅助参数设置

辅助标注、注释、矢量箭头

参考官方文档：https://bokeh.pydata.org/en/latest/docs/user_guide/annotations.html#color-bars

'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

import warnings
warnings.filterwarnings('ignore') 
# 不发出警告

from bokeh.io import output_notebook
output_notebook()
# 导入notebook绘图模块

from bokeh.plotting import figure,show
# 导入图表绘制、图标展示模块
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aadc6813-5f58-4675-84b3-2b82d707e9cb">Loading BokehJS ...</span>
#     </div>

# %%
# 辅助标注 - 线

from bokeh.models.annotations import Span
# 导入Span模块

x = np.linspace(0, 20, 200)
y = np.sin(x)
# 创建x，y数据

p = figure(y_range=(-2, 2))
p.line(x, y)
# 绘制曲线

upper = Span(location=1,           # 设置位置，对应坐标值
             dimension='width',    # 设置方向，width为横向，height为纵向  
             line_color='olive', line_width=4   # 设置线颜色、线宽
            )
p.add_layout(upper)
# 绘制辅助线1

lower = Span(location=-1, dimension='width', line_color='firebrick', line_width=4)
p.add_layout(lower)
# 绘制辅助线2

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dcb564a1-2e87-4b67-b4fa-7b1d3547aaf8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("dcb564a1-2e87-4b67-b4fa-7b1d3547aaf8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dcb564a1-2e87-4b67-b4fa-7b1d3547aaf8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dcb564a1-2e87-4b67-b4fa-7b1d3547aaf8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"658cfe5e-7a93-48ae-833a-cd1e20b0ebc7":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"f9688ff1-1524-4c9e-9879-477752078d50","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e50086a-d759-4e31-8185-be8fbb841fad","type":"BasicTicker"}},"id":"1a6e0284-c4b0-4597-9af1-8bc18608c269","type":"Grid"},{"attributes":{},"id":"d814be59-b9f0-4693-959f-3ad232f59acc","type":"HelpTool"},{"attributes":{},"id":"a4326eb9-8345-4252-a445-6060fa96e71b","type":"LinearScale"},{"attributes":{},"id":"e5ac2c3b-d030-4575-b18d-ec1d2df45f79","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0b6b0a07-53bc-44c1-a680-91c4ea038f39","type":"PanTool"},{"id":"32306c18-b6f6-4bf3-b41f-a18081241aca","type":"WheelZoomTool"},{"id":"a8d072af-c38b-40b2-b46c-1f45d5e8b404","type":"BoxZoomTool"},{"id":"ab9b5a81-1919-4be6-a202-c3a9a7e7a5a3","type":"SaveTool"},{"id":"da237a63-cded-4494-af71-a920ff5bc3d4","type":"ResetTool"},{"id":"d814be59-b9f0-4693-959f-3ad232f59acc","type":"HelpTool"}]},"id":"44c036dd-f3aa-4fea-9c3a-f5dd3d2e8e2e","type":"Toolbar"},{"attributes":{},"id":"da237a63-cded-4494-af71-a920ff5bc3d4","type":"ResetTool"},{"attributes":{"data_source":{"id":"37386780-611b-46e5-bf66-7884978b6b64","type":"ColumnDataSource"},"glyph":{"id":"041f536e-9fc2-4d93-b5ee-ed95f8ad04ac","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e86fb99a-fb96-443b-b319-e896d020d688","type":"Line"},"selection_glyph":null,"view":{"id":"9c6c37c2-8c84-48a2-8b43-ef2fb41b5962","type":"CDSView"}},"id":"26b152f9-4519-4081-ae96-dd711007770d","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"9392c573-7e93-41a7-b447-77af9056fb12","type":"Title"},{"attributes":{},"id":"3d3dd255-978a-4021-8aa8-fa0e01f17ae5","type":"BasicTicker"},{"attributes":{},"id":"0e27f033-4ed5-4192-a200-55c812488b8b","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"101ef9f1-5a04-415d-ab8d-80011796a43b","type":"DataRange1d"},{"attributes":{"plot":{"id":"f9688ff1-1524-4c9e-9879-477752078d50","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d3dd255-978a-4021-8aa8-fa0e01f17ae5","type":"BasicTicker"}},"id":"73cae6ef-e248-4f03-b3fa-5aacce08e66c","type":"Grid"},{"attributes":{},"id":"3e50086a-d759-4e31-8185-be8fbb841fad","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e86fb99a-fb96-443b-b319-e896d020d688","type":"Line"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":4},"location":-1,"plot":{"id":"f9688ff1-1524-4c9e-9879-477752078d50","subtype":"Figure","type":"Plot"}},"id":"3cbbb42b-b93c-48d5-a435-7c420e2d0d24","type":"Span"},{"attributes":{},"id":"04a0fc57-a364-4608-b03a-a651f44ef93f","type":"LinearScale"},{"attributes":{},"id":"32306c18-b6f6-4bf3-b41f-a18081241aca","type":"WheelZoomTool"},{"attributes":{},"id":"ab9b5a81-1919-4be6-a202-c3a9a7e7a5a3","type":"SaveTool"},{"attributes":{"formatter":{"id":"0e27f033-4ed5-4192-a200-55c812488b8b","type":"BasicTickFormatter"},"plot":{"id":"f9688ff1-1524-4c9e-9879-477752078d50","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e50086a-d759-4e31-8185-be8fbb841fad","type":"BasicTicker"}},"id":"091bc7b7-c5e5-48ef-87e4-898a2c95dc29","type":"LinearAxis"},{"attributes":{"line_color":{"value":"olive"},"line_width":{"value":4},"location":1,"plot":{"id":"f9688ff1-1524-4c9e-9879-477752078d50","subtype":"Figure","type":"Plot"}},"id":"41951699-5ce5-420a-bc34-97125f77c29e","type":"Span"},{"attributes":{"overlay":{"id":"c24906ce-f572-438d-b5eb-5ca4b7fdb6ba","type":"BoxAnnotation"}},"id":"a8d072af-c38b-40b2-b46c-1f45d5e8b404","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"041f536e-9fc2-4d93-b5ee-ed95f8ad04ac","type":"Line"},{"attributes":{"callback":null,"end":2,"start":-2},"id":"1d5f9e16-f371-4f71-9ccf-69c8096aeb5c","ty ...

# %%
# 辅助标注 - 矩形

from bokeh.models.annotations import BoxAnnotation
# 导入BoxAnnotation模块

x = np.linspace(0, 20, 200)
y = np.sin(x)
# 创建x，y数据

p = figure(y_range=(-2, 2))
p.line(x, y)
# 绘制曲线

upper = BoxAnnotation(bottom=1, fill_alpha=0.1, fill_color='olive')
p.add_layout(upper)
# 绘制辅助矩形1

lower = BoxAnnotation(top=-1, fill_alpha=0.1, fill_color='firebrick')
p.add_layout(lower)
# 绘制辅助矩形2

center = BoxAnnotation(top=0.6, bottom=-0.3, left=7, right=12,  # 设置矩形四边位置
                       fill_alpha=0.1, fill_color='navy'        # 设置透明度、颜色
                      )
p.add_layout(center)
# 绘制辅助矩形3

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d25c6572-acf2-4b6d-a287-dcf0f5bc77d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d25c6572-acf2-4b6d-a287-dcf0f5bc77d2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f53d8e91-97b4-43ae-a8e6-dac5e73d3b94","type":"Line"},"selection_glyph":null,"view":{"id":"1917cf85-1c79-4936-a56a-aac038ee0980","type":"CDSView"}},"id":"5fa8e3c4-5549-4cb4-aad5-886511d5e222","type":"GlyphRenderer"},{"attributes":{"source":{"id":"8b888c11-82b4-4a21-8d66-a5abd579b61a","type":"ColumnDataSource"}},"id":"1917cf85-1c79-4936-a56a-aac038ee0980","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"firebrick"},"plot":{"id":"e003094d-5052-4ea6-af0d-fa9e9dcc3a1e","subtype":"Figure","type":"Plot"},"top":-1},"id":"6a186aa6-b720-46a9-a078-99f2bfcf246c","type":"BoxAnnotation"},{"attributes":{},"id":"f657cbd0-6a85-49f0-8524-db1dee655a63","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e24ff3de-3382-43ed-8f93-e96c03c8c556","type":"PanTool"},{"id":"f657cbd0-6a85-49f0-8524-db1dee655a63","type":"WheelZoomTool"},{"id":"96e23643-d4a0-4f7b-9 ...

# %%
# 绘图注释

from bokeh.models.annotations import Label
# 导入Label模块，注意是annotations中的Label

p = figure(x_range=(0,10), y_range=(0,10))
p.circle([2, 5, 8], [4, 7, 6], color="olive", size=10)
# 绘制散点图

label = Label(x=5, y=7,       # 标注注释位置
              x_offset=12,    # x偏移，同理y_offset
              text="Second Point",      # 注释内容
              text_font_size="12pt",    # 字体大小
              border_line_color="red", background_fill_color="gray", background_fill_alpha = 0.5   # 背景线条颜色、背景颜色、透明度
             )
p.add_layout(label)
# 绘制注释

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="971e295a-bd1a-44e8-9926-5cf7f04c70c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("971e295a-bd1a-44e8-9926-5cf7f04c70c8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("971e295a-bd1a-44e8-9926-5cf7f04c70c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '971e295a-bd1a-44e8-9926-5cf7f04c70c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d6c8f50-ac6a-47c8-bb93-c5c56ee968af":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"0ba254eb-9ae0-4b5b-8e50-da98119e6662","type":"Title"},{"attributes":{"below":[{"id":"cb14f8ee-6e18-4581-9e94-ae14e6928676","type":"LinearAxis"}],"left":[{"id":"79fca64c-30be-44ca-b0b6-60220aeeb821","type":"LinearAxis"}],"renderers":[{"id":"cb14f8ee-6e18-4581-9e94-ae14e6928676","type":"LinearAxis"},{"id":"86504825-7d0a-4fc6-9f0d-c95d25be3256","type":"Grid"},{"id":"79fca64c-30be-44ca-b0b6-60220aeeb821","type":"LinearAxis"},{"id":"4bb3b266-d7aa-423f-8344-65dd04c437f6","type":"Grid"},{"id":"75f16da1-52cf-4b30-901e-6380f2169d13","type":"BoxAnnotation"},{"id":"7b63559a-9c42-4644-9030-2d565336038b","type":"GlyphRenderer"},{"id":"e6ecfacf-5b12-4642-8dd0-099b944a8910","type":"Label"}],"title":{"id":"0ba254eb-9ae0-4b5b-8e50-da98119e6662","type":"Title"},"toolbar":{"id":"c3d4c604-32a1-44a9-bfe3-ee071995272c","type":"Toolbar"},"x_range":{"id":"89108b44-67fb-4c53-b980-de4698dc6e8b","type":"Range1d"},"x_scale":{"id":"22ef5906-e786-43e7-803e-36aa79e1d922","type":"LinearScale"},"y_range":{"id":"11dbb1d4-f4f0-4005-abd5-b42cdde28ae2","type":"Range1d"},"y_scale":{"id":"19222f1b-d28b-41ae-b32f-91ab0dcca6b1","type":"LinearScale"}},"id":"c73d1372-f68a-4bcc-868e-59fb1718e8cf","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"c510a43c-711d-4559-844b-3f11d08d2f8f","type":"ColumnDataSource"}},"id":"3779a6af-b4da-4854-bd07-1957760ac10d","type":"CDSView"},{"attributes":{"callback":null,"end":10},"id":"11dbb1d4-f4f0-4005-abd5-b42cdde28ae2","type":"Range1d"},{"attributes":{"fill_color":{"value":"olive"},"line_color":{"value":"olive"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"835bc2f9-fba8-4ee0-aa5a-0e5cbbbdc084","type":"Circle"},{"attributes":{},"id":"04d0c070-241c-4733-afa2-83b3aaf30384","type":"HelpTool"},{"attributes":{},"id":"43fb9e9f-7529-4f30-a343-a7990468545b","type":"BasicTicker"},{"attributes":{"overlay":{"id":"75f16da1-52cf-4b30-901e-6380f2169d13","type":"BoxAnnotation"}},"id":"5ca2e8c8-9c38-4602-9fe8-3861a8d69f3b","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,5,8],"y":[4,7,6]}},"id":"c510a43c-711d-4559-844b-3f11d08d2f8f","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4eb1ab9e-5c97-4dbb-9888-21a169ea294c","type":"PanTool"},{"id":"f18b062f-ea6d-4da8-a3fe-f0c44221ca3b","type":"WheelZoomTool"},{"id":"5ca2e8c8-9c38-4602-9fe8-3861a8d69f3b","type":"BoxZoomTool"},{"id":"2232c8b2-81a2-41c3-9755-e409288555a5","type":"SaveTool"},{"id":"9e62f74e-cdf6-4c6f-b025-1ac58db277a4","type":"ResetTool"},{"id":"04d0c070-241c-4733-afa2-83b3aaf30384","type":"HelpTool"}]},"id":"c3d4c604-32a1-44a9-bfe3-ee071995272c","type":"Toolbar"},{"attributes":{"formatter":{"id":"b145cbd0-332a-4b98-9941-ab9cdb034057","type":"BasicTickFormatter"},"plot":{"id":"c73d1372-f68a-4bcc-868e-59fb1718e8cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"43fb9e9f-7529-4f30-a343-a7990468545b","type":"BasicTicker"}},"id":"cb14f8ee-6e18-4581-9e94-ae14e6928676","type":"LinearAxis"},{"attributes":{},"id":"22ef5906-e786-43e7-803e-36aa79e1d922","type":"LinearScale"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"gray"},"border_line_color":{"value":"red"},"plot":{"id":"c73d1372-f68a-4bcc-868e-59fb1718e8cf","subtype":"Figure","type":"Plot"},"text":"Second Point","x":5,"x_offset":12,"y":7},"id":"e6ecfacf-5b12-4642-8dd0-099b944a8910","type":"Label"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a59102ea-3efd-4f90-8a70-760d788bee77","type":"Circle"},{"attributes":{"plot":{"id":"c73d1372-f68a-4bcc-868e-59fb1718e8cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"43fb9e9 ...

# %%
# 注释箭头

from bokeh.models.annotations import Arrow
from bokeh.models.arrow_heads import OpenHead, NormalHead, VeeHead   # 三种箭头类型
# 导入相关模块

p = figure(plot_width=600, plot_height=600)
p.circle(x=[0, 1, 0.5], y=[0, 0, 0.7], radius=0.1, color=["navy", "yellow", "red"], fill_alpha=0.1)
# 创建散点图

p.add_layout(Arrow(end=OpenHead(line_color="firebrick", line_width=4),  # 设置箭头类型，及相关参数：OpenHead, NormalHead, VeeHead
                   x_start=0, y_start=0, x_end=1, y_end=0))   # 设置箭头矢量方向
# 绘制箭头1

p.add_layout(Arrow(end=NormalHead(fill_color="orange"),
                   x_start=1, y_start=0, x_end=0.5, y_end=0.7))
# 绘制箭头2

p.add_layout(Arrow(end=VeeHead(size=35), line_color="red",
                   x_start=0.5, y_start=0.7, x_end=0, y_end=0))
# 绘制箭头3

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f03252d-0ca0-4472-a6db-f6f705f8d66c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6f03252d-0ca0-4472-a6db-f6f705f8d66c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f03252d-0ca0-4472-a6db-f6f705f8d66c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f03252d-0ca0-4472-a6db-f6f705f8d66c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ebcb399-2f90-4ab7-ab58-72c40682d574":{"roots":{"references":[{"attributes":{},"id":"29ba459b-4618-417e-bb4f-bc9ba9b1fe71","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"0005d8bf-3e0d-4871-9299-5bf1b0b5cb83","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5010ac1-8984-41f9-8db1-261b535b49b1","type":"BasicTicker"}},"id":"58027baa-8090-4c19-bf8c-5bc9858bede7","type":"Grid"},{"attributes":{},"id":"49efcc85-ccbb-4cfd-bd0f-a2f34e7294a5","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"29ba459b-4618-417e-bb4f-bc9ba9b1fe71","type":"PanTool"},{"id":"090540dc-f070-4f02-99cb-b2d771107001","type":"WheelZoomTool"},{"id":"0f9ddcae-db9c-41d8-8460-5871b980903b","type":"BoxZoomTool"},{"id":"253ba4e8-cc06-4a11-9b3f-caf8db796066","type":"SaveTool"},{"id":"49efcc85-ccbb-4cfd-bd0f-a2f34e7294a5","type":"ResetTool"},{"id":"40a88cad-80f4-497f-bcf6-f2ebc5c09739","type":"HelpTool"}]},"id":"b0b9ff77-709d-421e-960e-8372e2da6fd3","type":"Toolbar"},{"attributes":{"data_source":{"id":"3853add6-d659-4f6c-b9f7-1b3e8c398762","type":"ColumnDataSource"},"glyph":{"id":"6bb6a6d2-d4f2-4f3d-bdf8-b0f2d6a472de","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b8656c57-f0de-48f6-a09b-917d6a759cb9","type":"Circle"},"selection_glyph":null,"view":{"id":"383b7d34-145e-4d78-af1a-bc6764ea673b","type":"CDSView"}},"id":"755db205-05c3-4084-a471-d4929c88bd07","type":"GlyphRenderer"},{"attributes":{},"id":"2396a874-8eea-49db-a9ce-a7dca7c578b9","type":"BasicTickFormatter"},{"attributes":{},"id":"9dae873a-480e-4e86-9acf-de722f7893ca","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0005d8bf-3e0d-4871-9299-5bf1b0b5cb83","subtype":"Figure","type":"Plot"},"ticker":{"id":"3789218d-817d-476e-b8e4-fea4d8aa3b5f","type":"BasicTicker"}},"id":"4c0a2234-df3f-43f9-90eb-086dbb97eade","type":"Grid"},{"attributes":{},"id":"e26528c5-8eb2-4971-b2e6-83466b50ba53","type":"LinearScale"},{"attributes":{"callback":null},"id":"071a0d37-279d-4225-aab4-f340ff9ab9a1","type":"DataRange1d"},{"attributes":{"formatter":{"id":"9dae873a-480e-4e86-9acf-de722f7893ca","type":"BasicTickFormatter"},"plot":{"id":"0005d8bf-3e0d-4871-9299-5bf1b0b5cb83","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5010ac1-8984-41f9-8db1-261b535b49b1","type":"BasicTicker"}},"id":"7d2ceecd-13a7-462d-8bcf-b9993cdcc3d1","type":"LinearAxis"},{"attributes":{"source":{"id":"3853add6-d659-4f6c-b9f7-1b3e8c398762","type":"ColumnDataSource"}},"id":"383b7d34-145e-4d78-af1a-bc6764ea673b","type":"CDSView"},{"attributes":{"callback":null},"id":"005bde62-c482-4757-a41d-6eab847041c0","type":"DataRange1d"},{"attributes":{"end":{"id":"e514a08b-66c7-420b-a1b9-471b6470cdf1","type":"NormalHead"},"plot":{"id":"0005d8bf-3e0d-4871-9299-5bf1b0b5cb83","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":0.5},"x_start":{"value":1},"y_end":{"value":0.7},"y_start":{"value":0}},"id":"e099ff4d-299d-4a78-9817-59e6f418f72d","type":"Arrow"},{"attributes":{"end":{"id":"51a37c03-fe99-48e3-bac9-0a3d0c5998df","type":"VeeHead"},"line_color":{"value":"red"},"plot":{"id":"0005d8bf-3e0d-4871-9299-5bf1b0b5cb83","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":0},"x_start":{"value":0.5},"y_end":{"value":0},"y_start":{"value":0.7}},"id":"6482f7aa-ae16-4d3e-9c03-9980b0efcc01","type":"Arrow"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"radius":{"units":"data","value":0.1},"x":{"field":"x"},"y":{"field":"y"}},"id":"6bb6a6d2-d4f2-4f3d-bdf8-b0f2d6a472de","type":"Circle"},{"attributes":{"below":[{"id":"035b9fa8-fd9e-489f-86f1-f050704f2aa3","type":"LinearAxis"}],"left":[{"id":"7d2ceecd-13a7-462d-8bcf-b9993cdcc3d1","type":"LinearAxis"}],"renderers":[{"id":"035b9fa8-fd9e-489f-86f1-f050704f2aa3","type":"LinearAxis"},{"id":"4c0a2234-df3f-43f9-90eb-086dbb97eade","type":"Grid"},{"id":"7d2ce ...

# %%
# 调色盘
# 颜色参考文档：http://bokeh.pydata.org/en/latest/docs/reference/palettes.html
# ColorBrewer：http://colorbrewer2.org/#type=sequential&scheme=BuGn&n=3

import bokeh.palettes as bp
from bokeh.palettes import brewer

print('所有调色板名称：\n',bp.__palettes__)
print('-------')
# 查看所有调色板名称

print('蓝色调色盘颜色：\n',bp.Blues)
print('-------')
# 查看蓝色调色盘颜色

n = 8
colori = brewer['YlGn'][n]   
print('YlGn调色盘解析为%i个颜色，分别为：\n' % n, colori)
# 调色盘解析 → 不同颜色解析最多颜色有限
# Out:
# 所有调色板名称：
Plasma6', 'Plasma7', 'Plasma8', 'Plasma9', 'Plasma10', 'Plasma11', 'Plasma256', 'PuBu3', 'PuBu4', 'PuBu5', 'PuBu6', 'PuBu7', 'PuBu8', 'PuBu9', 'PuBuGn3', 'PuBuGn4', 'PuBuGn5', 'PuBuGn6', 'PuBuGn7', 'PuBuGn8', 'PuBuGn9', 'PuOr3', 'PuOr4', 'PuOr5', 'PuOr6', 'PuOr7', 'PuOr8', 'PuOr9', 'PuOr10', 'PuOr11', 'PuRd3', 'PuRd4', 'PuRd5', 'PuRd6', 'PuRd7', 'PuRd8', 'PuRd9', 'Purples3', 'Purples4', 'Purples5', 'Purples6', 'Purples7', 'Purples8', 'Purples9', 'RdBu3', 'RdBu4', 'RdBu5', 'RdBu6', 'RdBu7', 'RdBu8', 'RdBu9', 'RdBu10', 'RdBu11', 'RdGy3', 'RdGy4', 'RdGy5', 'RdGy6', 'RdGy7', 'RdGy8', 'RdGy9', 'RdGy10', 'RdGy11', 'RdPu3', 'RdPu4', 'RdPu5', 'RdPu6', 'RdPu7', 'RdPu8', 'RdPu9', 'RdYlBu3', 'RdYlBu4', 'RdYlBu5', 'RdYlBu6', 'RdYlBu7', 'RdYlBu8', 'RdYlBu9', 'RdYlBu10', 'RdYlBu11', 'RdYlGn3', 'RdYlGn4', 'RdYlGn5', 'RdYlGn6', 'RdYlGn7', 'RdYlGn8', 'RdYlGn9', 'RdYlGn10', 'RdYlGn11', 'Reds3', 'Reds4', 'Reds5', 'Reds6', 'Reds7', 'Reds8', 'Reds9', 'Set1_3', 'Set1_4', 'Set1_5', 'Set1_6', 'Set1_7', 'Set1_8', 'Set1_9', 'Set2_3', 'Set2_4', 'Set2_5', 'Set2_6', 'Set2_7', 'Set2_8', 'Set3_3', 'Set3_4', 'Set3_5', 'Set3_6', 'Set3_7', 'Set3_8', 'Set3_9', 'Set3_10', 'Set3_11', 'Set3_12', 'Spectral3', 'Spectral4', 'Spectral5', 'Spectral6', 'Spectral7', 'Spectral8', 'Spectral9', 'Spectral10', 'Spectral11', 'Viridis3', 'Viridis4', 'Viridis5', 'Viridis6', 'Viridis7', 'Viridis8', 'Viridis9', 'Viridis10', ...
# -------
# 蓝色调色盘颜色：
#  {3: ['#3182bd', '#9ecae1', '#deebf7'], 4: ['#2171b5', '#6baed6', '#bdd7e7', '#eff3ff'], 5: ['#08519c', '#3182bd', '#6baed6', '#bdd7e7', '#eff3ff'], 6: ['#08519c', '#3182bd', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff'], 7: ['#084594', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff'], 8: ['#084594', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff'], 9: ['#08306b', '#08519c', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff']}
# -------
# YlGn调色盘解析为8个颜色，分别为：
#  ['#005a32', '#238443', '#41ab5d', '#78c679', '#addd8e', '#d9f0a3', '#f7fcb9', '#ffffe5']
