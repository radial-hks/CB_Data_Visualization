# %%
import requests

# %%
m = requests.get("http://dcfm.eastmoney.com/em_mutisvcexpandinterface/api/js/get?type=KZZ_LB2.0&token=70f12f2f4f091e459a279469fe49eca5&cmd=&st=STARTDATE&sr=-1&p=4&ps=100")

# %%
m.json()
# Out:
# [{'BONDCODE': '110227',
#   'TEXCH': 'CNSESH',
#   'BCODE': '07040500001THZ',
#   'SNAME': '赤化转债',
#   'STARTDATE': '2007-10-10T00:00:00',
#   'CORRESCODE': '733227',
#   'CORRESNAME': '赤化发债',
#   'SWAPSCODE': '600227',
#   'SECURITYSHORTNAME': '圣济堂',
#   'PARVALUE': 100.0,
#   'ISSUEPRICE': 100.0,
#   'SWAPPRICE': 24.93,
#   'ZQHDATE': '2007-10-16T00:00:00',
#   'LUCKRATE': 0.15885419,
#   'LISTDATE': '2007-10-23T00:00:00',
#   'DELISTDATE': '2009-06-02T00:00:00',
#   'MEMO': '',
#   'ZGJ': '-',
#   'MarketType': '1',
#   'HSCFJ': '-',
#   'QSCFJ': '-',
#   'PB': 1.2,
#   'GDYX_STARTDATE': '2007-10-09T00:00:00',
#   'NOTICEDATE_SH': '2009-04-27T00:00:00',
#   'STARTDATE_SH': '2009-05-25T00:00:00',
#   'PRICE_SH': 103.0,
#   'RECORDATE_SH': '-',
#   'EXECREASON_SH': 4.0,
#   'CALLSTYPE_SH': '2',
#   'NOTICEDATE_HS': '2008-09-24T00:00:00',
#   'STARTDATE_HS': '2008-10-10T00:00:00',
#   'ENDATE_HS': '2008-10-16T00:00:00',
#   'PRICE_HS': 103.0,
#   'EXECREASON_HS': '1',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-07b518266fb0> in <module>
# ----> 1 import HTMLParser
#
# ~/anaconda3/lib/python3.7/site-packages/HTMLParser.py in <module>
#       9
#      10
# ---> 11 import markupbase
#      12 import re
#      13
#
# ModuleNotFoundError: No module named 'markupbase'

# %%
m = requests.get("http://data.eastmoney.com/kzz/detail/110227.html")

# %%
m.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n<!--published at 2019-12-14 19:39:51-->\r\n<head><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta http-equiv="Content-Type" content="text/html; charset=gb2312" /><meta name="viewport" content="width=device-width" /><meta name="format-detection" content="telephone=no" /><link rel="shortcut icon" type="image/ico" href="http://www.eastmoney.com/favicon.ico" />\r\n    <link href="/css_001/master.css" rel="stylesheet" />\r\n    <link rel="stylesheet" type="text/css" media="all" href="/css_001/default.css?rt=20160616" /><link rel="stylesheet" type="text/css" media="all" href="/css_001/layer2012.css?rt=20120717" />\r\n    <script src="/js_001/ht_web.js?2019"></script>\r\n    <script type="text/javascript" src="//cmsjs.eastmoney.com/channel/jquery-1.8.3.min.js?rt=20151113"></script>\r\n    <script type="text/javascript">\r\n        var jQuery = $.noConflict();\r\n    </script>\r\n    <script src="//emchart
# ...

# %%
import tushare as ts

# %%
import tushare as ts
# tushare 提供的数据 ：茅台
ts.get_hist_data('600519')


# 这个是你同学的数据
# [20191213,1146.00,1165.00,1146.00,1163.00,3000059]
# Out:
#                open     high    close      low    volume  price_change  \
# date
# 2019-12-13  1146.00  1165.00  1163.00  1146.00  30000.59         26.00
# 2019-12-12  1156.00  1159.94  1137.00  1130.08  29409.16        -21.98
# 2019-12-11  1168.00  1170.75  1158.98  1155.55  14567.99         -5.42
# 2019-12-10  1159.60  1165.00  1164.40  1151.00  15086.58          5.70
# 2019-12-09  1175.00  1176.00  1158.70  1156.10  21824.12        -11.30
# ...             ...      ...      ...      ...       ...           ...
# 2017-06-20   473.00   474.88   466.30   465.66  34505.39         -3.87
# 2017-06-19   461.96   470.39   470.17   461.96  38536.68          7.54
# 2017-06-16   461.50   467.49   462.63   461.26  33331.80         -1.67
# 2017-06-15   475.00   475.48   464.30   464.00  50202.80        -10.09
# 2017-06-14   472.79   477.50   474.39   470.48  33768.63          1.35
#
#             p_change       ma5      ma10      ma20     v_ma5    v_ma10  \
# date
# ...
